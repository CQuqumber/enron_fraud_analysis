# %% [markdown]
# # Enron Fruad

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib notebook
from scipy.stats import trim_mean
import seaborn as sns
import numpy as np
import pandas as pd
import sys
import pickle
from feature_format import featureFormat
from feature_format import targetFeatureSplit

from sklearn.ensemble import GradientBoostingClassifier

features_list = ["poi"]

data_dict = pickle.load(open("final_project_dataset.pkl", "r") )

clf = GradientBoostingClassifier()   

pickle.dump(clf, open("my_classifier.pkl", "w") )
pickle.dump(data_dict, open("my_dataset.pkl", "w") )
pickle.dump(features_list, open("my_feature_list.pkl", "w") )
# Out:
# /Users/Joel/anaconda/envs/py2/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## 数据探索
# - 数据点总数
# - 类之间的分配（POI/非 POI）
# - 使用的特征数量
# - 是否有哪些特征有很多缺失值？等。

# %%
df = pd.DataFrame(data_dict).T
df.head()
# Out:
#                       bonus deferral_payments deferred_income director_fees  \
# ALLEN PHILLIP K     4175000           2869717        -3081055           NaN
# BADUM JAMES P           NaN            178980             NaN           NaN
# BANNANTINE JAMES M      NaN               NaN           -5104           NaN
# BAXTER JOHN C       1200000           1295738        -1386055           NaN
# BAY FRANKLIN R       400000            260455         -201641           NaN
#
#                                  email_address exercised_stock_options  \
# ALLEN PHILLIP K        phillip.allen@enron.com                 1729541
# BADUM JAMES P                              NaN                  257817
# BANNANTINE JAMES M  james.bannantine@enron.com                 4046157
# BAXTER JOHN C                              NaN                 6680544
# BAY FRANKLIN R             frank.bay@enron.com                     NaN
#
#                    expenses from_messages from_poi_to_this_person  \
# ALLEN PHILLIP K       13868          2195                      47
# BADUM JAMES P          3486           NaN                     NaN
# BANNANTINE JAMES M    56301            29                      39
# BAXTER JOHN C         11200           NaN                     NaN
# BAY FRANKLIN R       129142           NaN                     NaN
#
#                    from_this_person_to_poi        ...         \
# ALLEN PHILLIP K                         65        ...
# BADUM JAMES P                          NaN        ...
# BANNANTINE JAMES M                       0        ...
# BAXTER JOHN C                          NaN        ...
# BAY FRANKLIN R                         NaN        ...
#
#                    long_term_incentive    other    poi restricted_stock  \
# ALLEN PHILLIP K                 304805      152  False           126027
# BADUM JAMES P                      NaN      NaN  False              NaN
# BANNANTINE JAMES M                 NaN   864523  False          1757552
# BAXTER JOHN C                  1586055  2660303  False          3942714
# BAY FRANKLIN R                     NaN       69  False           145796
#
#                    restricted_stock_deferred  salary shared_receipt_with_poi  \
# ALLEN PHILLIP K                      -126027  201955                    1407
# BADUM JAMES P                            NaN     NaN                     NaN
# BANNANTINE JAMES M                   -560222     477                     465
# BAXTER JOHN C                            NaN  267102                     NaN
# BAY FRANKLIN R                        -82782  239671                     NaN
#
#                    to_messages total_payments total_stock_value
# ALLEN PHILLIP K           2902        4484442           1729541
# BADUM JAMES P              NaN         182466            257817
# BANNANTINE JAMES M         566         916197           5243487
# BAXTER JOHN C              NaN        5634343          10623258
# BAY FRANKLIN R             NaN         827696             63014
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 数据点总数
# - 146嫌疑犯，21個特征，包含「财务特征」，「邮件特征」，「POI 标签」

# %%
df.shape
# Out:
# (146, 21)

# %% [markdown]
# ### 类之间的分配
#
# - 「财务特征」為 Numerical
#
# - 「邮件特征」為 Numerical / Text
#
# - 「POI标签」為 Categorical

# %%
df.dtypes
# Out:
# bonus                        object
# deferral_payments            object
# deferred_income              object
# director_fees                object
# email_address                object
# exercised_stock_options      object
# expenses                     object
# from_messages                object
# from_poi_to_this_person      object
# from_this_person_to_poi      object
# loan_advances                object
# long_term_incentive          object
# other                        object
# poi                          object
# restricted_stock             object
# restricted_stock_deferred    object
# salary                       object
# shared_receipt_with_poi      object
# to_messages                  object
# total_payments               object
# total_stock_value            object
# dtype: object

# %%
df.columns.values
flt_col = ['bonus', 'deferral_payments', 'deferred_income', 'director_fees',
       'exercised_stock_options', 'expenses',
       'from_messages', 'from_poi_to_this_person',
       'from_this_person_to_poi', 'loan_advances', 'long_term_incentive',
       'other', 'restricted_stock', 'restricted_stock_deferred',
       'salary', 'shared_receipt_with_poi', 'to_messages',
       'total_payments', 'total_stock_value']

# %% [markdown]
# ### 把「email_address」，「poi」以外做轉換型態

# %%
df[flt_col] = df[flt_col].apply(pd.to_numeric, errors='coerce')
df.dtypes
# Out:
# bonus                        float64
# deferral_payments            float64
# deferred_income              float64
# director_fees                float64
# email_address                 object
# exercised_stock_options      float64
# expenses                     float64
# from_messages                float64
# from_poi_to_this_person      float64
# from_this_person_to_poi      float64
# loan_advances                float64
# long_term_incentive          float64
# other                        float64
# poi                           object
# restricted_stock             float64
# restricted_stock_deferred    float64
# salary                       float64
# shared_receipt_with_poi      float64
# to_messages                  float64
# total_payments               float64
# total_stock_value            float64
# dtype: object

# %% [markdown]
# ### 使用的特征数量
# ### 是否有哪些特征有很多缺失值？等

# %%
df_miss = df.select_dtypes(include = ['float64', 'int64'])#.iloc[:, 1:]
total = df_miss.isnull().sum().sort_values(ascending=False)
pd.DataFrame(total, columns=['Missing Values'])
# Out:
#                            Missing Values
# loan_advances                         142
# director_fees                         129
# restricted_stock_deferred             128
# deferral_payments                     107
# deferred_income                        97
# long_term_incentive                    80
# bonus                                  64
# from_this_person_to_poi                60
# from_poi_to_this_person                60
# from_messages                          60
# shared_receipt_with_poi                60
# to_messages                            60
# other                                  53
# expenses                               51
# salary                                 51
# exercised_stock_options                44
# restricted_stock                       36
# total_payments                         21
# total_stock_value                      20

# %% [markdown]
# ### 遺失值過多的Feature，丟失過多數據，不適用填充值方式取代
# - loan_advances	142
# - director_fees	129
# - restricted_stock_deferred	128
# - deferral_payments	107
# - deferred_income	97
# - long_term_incentive	80
#
# ### 遺失值比較少的Feature
# - exercised_stock_options	44
# - restricted_stock	36
# - total_payments	21
# - total_stock_value	20
#
#
# #### 針對遺失值較少的處理方式
# - 透過相關性，檢查是跟否存在規律

# %%
dropf = ['loan_advances','director_fees','restricted_stock_deferred',
         'deferral_payments','deferred_income','long_term_incentive']

# 移除遺失過多的feature
df_less = df.drop(dropf ,axis=1).copy()

corrmat = df_less.select_dtypes(include = ['float64', 'int64']).corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True, cmap='viridis', square=True);
plt.xticks(rotation=90) 
plt.yticks(rotation=0)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# (array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#           9.5,  10.5,  11.5,  12.5]), <a list of 13 Text yticklabel objects>)

# %% [markdown]
# 高度相關性的特徵值
# **bonus, exercised_stock_options, expense, other, restricted_stock, salary, total_payments, total_stock_value**
#
# ### 處理遺失值
#  - 嘗試用**Regression**方式，能否預測出遺失值少的 **total_stock_value，total_payments**
#      1. 先把以上Features，移除NaN，看剩下多少樣本數
#      2. 如果數量夠，就採用Train/test split，去做訓練，驗證評估：R Square數值。

# %%
candidate = [ 'bonus', 'exercised_stock_options', 'expenses', 'other', 'restricted_stock', 'salary', 'total_payments', 'total_stock_value']
df_less = df_less[candidate].fillna(0)

# %%
df_less = df_less[df_less['bonus']>0]
df_less = df_less[df_less['salary']>0]
df_less = df_less[df_less['total_stock_value']>0]
df_less = df_less[df_less['total_payments']>0]
df_less.shape
# Out:
# (79, 8)

# %% [markdown]
# - 樣本數只有79個，先做數據處理

# %%
from sklearn.model_selection import train_test_split
train = df_less[['bonus','salary','total_stock_value']]
y_train = df_less.total_payments
Xtrain, Xtest, ytrain, ytest = train_test_split(train, y_train, test_size = 0.4, random_state = None)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
Stand = StandardScaler()
Xtrain = Stand.fit_transform(Xtrain)
Xtest = Stand.fit_transform(Xtest)
#ytrain = np.log10(ytrain) 
#ytest = np.log10(ytest)

# %% [markdown]
# ### Regressor 回歸模型
# 1. GradientBoostingRegressor
# 2. RandomForestRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
gb_reg = GradientBoostingRegressor()
rf_reg = RandomForestRegressor()

gb_reg.fit(Xtrain, ytrain)
rf_reg.fit(Xtrain, ytrain)

ygb_pred = gb_reg.predict(Xtest)
yrf_pred = rf_reg.predict(Xtest)
print('GBR R Square: %d'%(r2_score(ytest, ygb_pred)))
print('RF R Square: %d'%(r2_score(ytest, yrf_pred)))
print('GBR MAE: %d'%(mean_squared_error(ytest, ygb_pred)))
print('RF MAE: %d'%(mean_squared_error(ytest, yrf_pred)))
# Out:
# GBR R Square: -1
# RF R Square: 0
# GBR MAE: 693093869392141
# RF MAE: 444794522542109

# %% [markdown]
# ### 結論：Regression 插值，全部不可行，Std 過大

# %% [markdown]
# ### 處理遺失值，把NaN全部改成0
# - Std過大，不適合用interpolate內插法
# - 樣本過少，不適合插入中位數，或是平均值

# %%
df = df.fillna(0)
df.head()
# Out:
#                         bonus  deferral_payments  deferred_income  \
# ALLEN PHILLIP K     4175000.0          2869717.0       -3081055.0
# BADUM JAMES P             0.0           178980.0              0.0
# BANNANTINE JAMES M        0.0                0.0          -5104.0
# BAXTER JOHN C       1200000.0          1295738.0       -1386055.0
# BAY FRANKLIN R       400000.0           260455.0        -201641.0
#
#                     director_fees               email_address  \
# ALLEN PHILLIP K               0.0     phillip.allen@enron.com
# BADUM JAMES P                 0.0                         NaN
# BANNANTINE JAMES M            0.0  james.bannantine@enron.com
# BAXTER JOHN C                 0.0                         NaN
# BAY FRANKLIN R                0.0         frank.bay@enron.com
#
#                     exercised_stock_options  expenses  from_messages  \
# ALLEN PHILLIP K                   1729541.0   13868.0         2195.0
# BADUM JAMES P                      257817.0    3486.0            0.0
# BANNANTINE JAMES M                4046157.0   56301.0           29.0
# BAXTER JOHN C                     6680544.0   11200.0            0.0
# BAY FRANKLIN R                          0.0  129142.0            0.0
#
#                     from_poi_to_this_person  from_this_person_to_poi  \
# ALLEN PHILLIP K                        47.0                     65.0
# BADUM JAMES P                           0.0                      0.0
# BANNANTINE JAMES M                     39.0                      0.0
# BAXTER JOHN C                           0.0                      0.0
# BAY FRANKLIN R                          0.0                      0.0
#
#                           ...          long_term_incentive      other    poi  \
# ALLEN PHILLIP K           ...                     304805.0      152.0  False
# BADUM JAMES P             ...                          0.0        0.0  False
# BANNANTINE JAMES M        ...                          0.0   864523.0  False
# BAXTER JOHN C             ...                    1586055.0  2660303.0  False
# BAY FRANKLIN R            ...                          0.0       69.0  False
#
#                     restricted_stock  restricted_stock_deferred    salary  \
# ALLEN PHILLIP K             126027.0                  -126027.0  201955.0
# BADUM JAMES P                    0.0                        0.0       0.0
# BANNANTINE JAMES M         1757552.0                  -560222.0     477.0
# BAXTER JOHN C              3942714.0                        0.0  267102.0
# BAY FRANKLIN R              145796.0                   -82782.0  239671.0
#
#                     shared_receipt_with_poi  to_messages  total_payments  \
# ALLEN PHILLIP K                      1407.0       2902.0       4484442.0
# BADUM JAMES P                           0.0          0.0        182466.0
# BANNANTINE JAMES M                    465.0        566.0        916197.0
# BAXTER JOHN C                           0.0          0.0       5634343.0
# BAY FRANKLIN R                          0.0          0.0        827696.0
#
#                     total_stock_value
# ALLEN PHILLIP K             1729541.0
# BADUM JAMES P                257817.0
# BANNANTINE JAMES M          5243487.0
# BAXTER JOHN C              10623258.0
# BAY FRANKLIN R                63014.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Email Address 遺失值處理
# - 邮件特征得知，最高訊息含量的，會跟poi有關，郵箱地址沒有什麼訊息含量

# %%
df = df.drop('email_address', axis = 1)

# %% [markdown]
# ### 特征Poi處理
# - 沒有存在遺失值
# - 進行LabelEncoder編碼處理

# %%
df['poi'].unique()
# Out:
# array([False,  True], dtype=bool)

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df['poi'] = label.fit_transform(df['poi'])
df['poi'].tail()
# Out:
# WINOKUR JR. HERBERT S    0
# WODRASKA JOHN            0
# WROBEL BRUCE             0
# YEAGER F SCOTT           1
# YEAP SOON                0
# Name: poi, dtype: int64

# %% [markdown]
# ## 异常值调查

# %%
for i in flt_col:
    fig, ax = plt.subplots(figsize=(5, 5))
    df.boxplot(i, showfliers=True)
    #sns.boxplot(i, data=df)
    #sns.stripplot(i, data=df, jitter=True);
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">

# %%
plt.scatter(df['salary'], df['bonus'], alpha=.5, edgecolors='face')
plt.xlabel("Salary")
plt.ylabel("Bonus")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 找出 outlier

# %%
df[df['salary']>2.5e7]
# Out:
#             bonus  deferral_payments  deferred_income  director_fees  \
# TOTAL  97343619.0         32083396.0      -27992891.0      1398517.0
#
#       email_address  exercised_stock_options   expenses  from_messages  \
# TOTAL           NaN              311764000.0  5235198.0            NaN
#
#        from_poi_to_this_person  from_this_person_to_poi        ...          \
# TOTAL                      NaN                      NaN        ...
#
#        long_term_incentive       other    poi restricted_stock  \
# TOTAL           48521928.0  42667589.0  False      130322299.0
#
#        restricted_stock_deferred      salary  shared_receipt_with_poi  \
# TOTAL                 -7576788.0  26704229.0                      NaN
#
#        to_messages  total_payments  total_stock_value
# TOTAL          NaN     309886585.0        434509511.0
#
# [1 rows x 21 columns]

# %%
df.drop('TOTAL', axis = 0, inplace = True)

# %%
df[df['salary']>2.5e7]
# Out:
# Empty DataFrame
# Columns: [bonus, deferral_payments, deferred_income, director_fees, email_address, exercised_stock_options, expenses, from_messages, from_poi_to_this_person, from_this_person_to_poi, loan_advances, long_term_incentive, other, poi, restricted_stock, restricted_stock_deferred, salary, shared_receipt_with_poi, to_messages, total_payments, total_stock_value]
# Index: []
#
# [0 rows x 21 columns]

# %%
plt.scatter(df['salary'], df['bonus'], alpha=.5, edgecolors='face')
plt.xlabel("Salary")
plt.ylabel("Bonus")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(df['salary'], df['total_payments'], alpha=.5, edgecolors='face')
plt.xlabel("Salary")
plt.ylabel("Total Payments")
plt.show()

# %%
corrmat = df.select_dtypes(include = ['float64', 'int64']).corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
plt.xticks(rotation=90) 
plt.yticks(rotation=0)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# (array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#           9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,  18.5]),
#  <a list of 19 Text yticklabel objects>)

# %% [markdown]
# - 檢視NaN

# %%
df[df['total_stock_value'].isnull()==False]
# Out:
#                                  bonus  deferral_payments  deferred_income  \
# ALLEN PHILLIP K              4175000.0          2869717.0       -3081055.0
# BADUM JAMES P                      NaN           178980.0              NaN
# BANNANTINE JAMES M                 NaN                NaN          -5104.0
# BAXTER JOHN C                1200000.0          1295738.0       -1386055.0
# BAY FRANKLIN R                400000.0           260455.0        -201641.0
# BAZELIDES PHILIP J                 NaN           684694.0              NaN
# BECK SALLY W                  700000.0                NaN              NaN
# BELDEN TIMOTHY N             5249999.0          2144013.0       -2334434.0
# BELFER ROBERT                      NaN          -102500.0              NaN
# BERBERIAN DAVID                    NaN                NaN              NaN
# BERGSIEKER RICHARD P          250000.0                NaN        -485813.0
# BIBI PHILIPPE A              1000000.0                NaN              NaN
# BLACHMAN JEREMY M             850000.0                NaN              NaN
# BOWEN JR RAYMOND M           1350000.0                NaN           -833.0
# BUCHANAN HAROLD G             500000.0                NaN              NaN
# BUTTS ROBERT H                750000.0                NaN         -75000.0
# BUY RICHARD B                 900000.0           649584.0        -694862.0
# CALGER CHRISTOPHER F         1250000.0                NaN        -262500.0
# CAUSEY RICHARD A             1000000.0                NaN        -235000.0
# CHRISTODOULOU DIOMEDES             NaN                NaN              NaN
# CLINE KENNETH W                    NaN                NaN              NaN
# COLWELL WESLEY               1200000.0            27610.0        -144062.0
# CORDES WILLIAM R                   NaN                NaN              NaN
# COX DAVID                     800000.0                NaN         -41250.0
# CUMBERLAND MICHAEL S          325000.0                NaN              NaN
# DEFFNER JOSEPH M              600000.0                NaN              NaN
# DELAINEY DAVID W             3000000.0                NaN              NaN
# DERRICK JR. JAMES V           800000.0                NaN       -1284000.0
# DETMERING TIMOTHY J           425000.0           875307.0        -775241.0
# DIETRICH JANET R              600000.0                NaN              NaN
# ...                                ...                ...              ...
# PIRO JIM                           NaN                NaN              NaN
# PRENTICE JAMES                     NaN           564348.0              NaN
# REDMOND BRIAN L                    NaN                NaN              NaN
# REYNOLDS LAWRENCE             100000.0            51365.0        -200000.0
# RICE KENNETH D               1750000.0                NaN       -3504386.0
# RIEKER PAULA H                700000.0           214678.0        -100000.0
# SCRIMSHAW MATTHEW                  NaN                NaN              NaN
# SHANKMAN JEFFREY A           2000000.0                NaN              NaN
# SHAPIRO RICHARD S             650000.0                NaN              NaN
# SHARP VICTORIA T              600000.0           187469.0              NaN
# SHELBY REX                    200000.0                NaN          -4167.0
# SHERRICK JEFFREY B                 NaN                NaN              NaN
# SHERRIFF JOHN R              1500000.0                NaN              NaN
# SKILLING JEFFREY K           5600000.0                NaN              NaN
# STABLER FRANK                 500000.0                NaN              NaN
# SULLIVAN-SHAKLOVITZ COLLEEN   100000.0           181993.0              NaN
# SUNDE MARTIN                  700000.0                NaN              NaN
# TAYLOR MITCHELL S             600000.0           227449.0              NaN
# THORN TERENCE H                    NaN            16586.0              NaN
# TILNEY ELIZABETH A            300000.0                NaN        -575000.0
# WALLS JR ROBERT H             850000.0                NaN              NaN
# WALTERS GARETH W                   NaN            53625.0              NaN
# WASAFF GEORGE                 325000.0           831299.0        -583325.0
# WESTFAHL RICHARD K                 NaN                NaN         -10800.0
# WHALEY DAVID A                     NaN                NaN              NaN
# WHALLEY LAWRENCE G           3000000.0                NaN              NaN
# WHITE JR THOMAS E             450000.0                NaN              NaN
# WROBEL BRUCE                       NaN                NaN              NaN
# YEAGER F SCOTT                     NaN                NaN              NaN
# YEAP SOON                          NaN                NaN              NaN
#
#                              director_fees                     email_address  \
# ALLEN PHILLIP K                        NaN           phillip.allen@enron.com
# BADUM JAMES P                          NaN                               NaN
# BANNANTINE JAMES M                     NaN        james.bannantine@enron.com
# BAXTER JOHN C                          NaN                               NaN
# BAY FRANKLIN R                         NaN               frank.bay@enron.com
# BAZELIDES PHILIP J                     NaN                               NaN
# BECK SALLY W                           NaN              sally.beck@enron.com
# BELDEN TIMOTHY N                       NaN              tim.belden@enron.com
# BELFER ROBERT                       3285.0                               NaN
# BERBERIAN DAVID                        NaN         david.berberian@enron.com
# BERGSIEKER RICHARD P                   NaN         rick.bergsieker@enron.com
# BIBI PHILIPPE A                        NaN           philippe.bibi@enron.com
# BLACHMAN JEREMY M                      NaN         jeremy.blachman@enron.com
# BOWEN JR RAYMOND M                     NaN           raymond.bowen@enron.com
# BUCHANAN HAROLD G                      NaN           john.buchanan@enron.com
# BUTTS ROBERT H                         NaN               bob.butts@enron.com
# BUY RICHARD B                          NaN                rick.buy@enron.com
# CALGER CHRISTOPHER F                   NaN      christopher.calger@enron.com
# CAUSEY RICHARD A                       NaN          richard.causey@enron.com
# CHRISTODOULOU DIOMEDES                 NaN  diomedes.christodoulou@enron.com
# CLINE KENNETH W                        NaN                               NaN
# COLWELL WESLEY                         NaN             wes.colwell@enron.com
# CORDES WILLIAM R                       NaN             bill.cordes@enron.com
# COX DAVID                              NaN                chip.cox@enron.com
# CUMBERLAND MICHAEL S                   NaN                               NaN
# DEFFNER JOSEPH M                       NaN          joseph.deffner@enron.com
# DELAINEY DAVID W                       NaN          david.delainey@enron.com
# DERRICK JR. JAMES V                    NaN           james.derrick@enron.com
# DETMERING TIMOTHY J                    NaN       timothy.detmering@enron.com
# DIETRICH JANET R                       NaN          janet.dietrich@enron.com
# ...                                    ...                               ...
# PIRO JIM                               NaN                jim.piro@enron.com
# PRENTICE JAMES                         NaN          james.prentice@enron.com
# REDMOND BRIAN L                        NaN           brian.redmond@enron.com
# REYNOLDS LAWRENCE                      NaN                               NaN
# RICE KENNETH D                         NaN                ken.rice@enron.com
# RIEKER PAULA H                         NaN            paula.rieker@enron.com
# SCRIMSHAW MATTHEW                      NaN       matthew.scrimshaw@enron.com
# SHANKMAN JEFFREY A                     NaN        jeffrey.shankman@enron.com
# SHAPIRO RICHARD S                      NaN         richard.shapiro@enron.com
# SHARP VICTORIA T                       NaN             vicki.sharp@enron.com
# SHELBY REX                             NaN              rex.shelby@enron.com
# SHERRICK JEFFREY B                     NaN        jeffrey.sherrick@enron.com
# SHERRIFF JOHN R                        NaN           john.sherriff@enron.com
# SKILLING JEFFREY K                     NaN           jeff.skilling@enron.com
# STABLER FRANK                          NaN           frank.stabler@enron.com
# SULLIVAN-SHAKLOVITZ COLLEEN            NaN                               NaN
# SUNDE MARTIN                           NaN             marty.sunde@enron.com
# TAYLOR MITCHELL S                      NaN         mitchell.taylor@enron.com
# THORN TERENCE H                        NaN           terence.thorn@enron.com
# TILNEY ELIZABETH A                     NaN        elizabeth.tilney@enron.com
# WALLS JR ROBERT H                      NaN               rob.walls@enron.com
# WALTERS GARETH W                       NaN                               NaN
# WASAFF GEORGE                          NaN           george.wasaff@enron.com
# WESTFAHL RICHARD K                     NaN           dick.westfahl@enron.com
# WHALEY DAVID A                         NaN                               NaN
# WHALLEY LAWRENCE G                     NaN            greg.whalley@enron.com
# WHITE JR THOMAS E                      NaN            thomas.white@enron.com
# TILNEY ELIZABETH A                          591250.0       NaN           19.0
# WALLS JR ROBERT H                          4346544.0   50936.0          146.0
# WALTERS GARETH W                           1030329.0   33785.0            NaN
# WASAFF GEORGE                              1668260.0       NaN           30.0
# WESTFAHL RICHARD K                               NaN   51870.0            NaN
# WHALEY DAVID A                               98718.0       NaN            NaN
# WHALLEY LAWRENCE G                         3282960.0   57838.0          556.0
# WHITE JR THOMAS E                          1297049.0   81353.0            NaN
# WROBEL BRUCE                                139130.0       NaN            NaN
# YEAGER F SCOTT                             8308552.0   53947.0            NaN
# YEAP SOON                                   192758.0   55097.0            NaN
#
#                              from_poi_to_this_person  from_this_person_to_poi  \
# ALLEN PHILLIP K                                 47.0                     65.0
# BADUM JAMES P                                    NaN                      NaN
# BANNANTINE JAMES M                              39.0                      0.0
# BAXTER JOHN C                                    NaN                      NaN
# BAY FRANKLIN R                                   NaN                      NaN
# BAZELIDES PHILIP J                               NaN                      NaN
# BECK SALLY W                                   144.0                    386.0
# BELDEN TIMOTHY N                               228.0                    108.0
# BELFER ROBERT                                    NaN                      NaN
# BERBERIAN DAVID                                  NaN                      NaN
# BERGSIEKER RICHARD P                             4.0                      0.0
# BIBI PHILIPPE A                                 23.0                      8.0
# BLACHMAN JEREMY M                               25.0                      2.0
# BOWEN JR RAYMOND M                             140.0                     15.0
# BUCHANAN HAROLD G                                0.0                      0.0
# BUTTS ROBERT H                                   NaN                      NaN
# BUY RICHARD B                                  156.0                     71.0
# CALGER CHRISTOPHER F                           199.0                     25.0
# CAUSEY RICHARD A                                58.0                     12.0
# CHRISTODOULOU DIOMEDES                           NaN                      NaN
# CLINE KENNETH W                                  NaN                      NaN
# COLWELL WESLEY                                 240.0                     11.0
# CORDES WILLIAM R                                10.0                      0.0
# COX DAVID                                        0.0                      4.0
# CUMBERLAND MICHAEL S                             NaN                      NaN
# DEFFNER JOSEPH M                               115.0                      4.0
# DELAINEY DAVID W                                66.0                    609.0
# DERRICK JR. JAMES V                             64.0                     20.0
# DETMERING TIMOTHY J                              NaN                      NaN
# DIETRICH JANET R                               305.0                     14.0
# ...                                              ...                      ...
# PIRO JIM                                         0.0                      1.0
# PRENTICE JAMES                                   NaN                      NaN
# REDMOND BRIAN L                                204.0                     49.0
# REYNOLDS LAWRENCE                                NaN                      NaN
# RICE KENNETH D                                  42.0                      4.0
# RIEKER PAULA H                                  35.0                     48.0
# SCRIMSHAW MATTHEW                                NaN                      NaN
# SHANKMAN JEFFREY A                              94.0                     83.0
# SHAPIRO RICHARD S                               74.0                     65.0
# SHARP VICTORIA T                                24.0                      6.0
# SHELBY REX                                      13.0                     14.0
# SHERRICK JEFFREY B                              39.0                     18.0
# SHERRIFF JOHN R                                 28.0                     23.0
# SKILLING JEFFREY K                              88.0                     30.0
# STABLER FRANK                                    NaN                      NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                      NaN                      NaN
# SUNDE MARTIN                                    37.0                     13.0
# TAYLOR MITCHELL S                                0.0                      0.0
# THORN TERENCE H                                  0.0                      0.0
# TILNEY ELIZABETH A                              10.0                     11.0
# WALLS JR ROBERT H                               17.0                      0.0
# WALTERS GARETH W                                 NaN                      NaN
# WASAFF GEORGE                                   22.0                      7.0
# WESTFAHL RICHARD K                               NaN                      NaN
# WHALEY DAVID A                                   NaN                      NaN
# WHALLEY LAWRENCE G                             186.0                     24.0
# WHITE JR THOMAS E                                NaN                      NaN
# WROBEL BRUCE                                     NaN                      NaN
# YEAGER F SCOTT                                   NaN                      NaN
# YEAP SOON                                        NaN                      NaN
#
#                                    ...          long_term_incentive  \
# ALLEN PHILLIP K                    ...                     304805.0
# BADUM JAMES P                      ...                          NaN
# BANNANTINE JAMES M                 ...                          NaN
# BAXTER JOHN C                      ...                    1586055.0
# BAY FRANKLIN R                     ...                          NaN
# BAZELIDES PHILIP J                 ...                      93750.0
# BECK SALLY W                       ...                          NaN
# BELDEN TIMOTHY N                   ...                          NaN
# BELFER ROBERT                      ...                          NaN
# BERBERIAN DAVID                    ...                          NaN
# BERGSIEKER RICHARD P               ...                     180250.0
# BIBI PHILIPPE A                    ...                     369721.0
# BLACHMAN JEREMY M                  ...                     831809.0
# BOWEN JR RAYMOND M                 ...                     974293.0
# BUCHANAN HAROLD G                  ...                     304805.0
# BUTTS ROBERT H                     ...                     175000.0
# BUY RICHARD B                      ...                     769862.0
# CALGER CHRISTOPHER F               ...                     375304.0
# CAUSEY RICHARD A                   ...                     350000.0
# CHRISTODOULOU DIOMEDES             ...                          NaN
# CLINE KENNETH W                    ...                          NaN
# COLWELL WESLEY                     ...                          NaN
# CORDES WILLIAM R                   ...                          NaN
# COX DAVID                          ...                          NaN
# CUMBERLAND MICHAEL S               ...                     275000.0
# DEFFNER JOSEPH M                   ...                     335349.0
# DELAINEY DAVID W                   ...                    1294981.0
# DERRICK JR. JAMES V                ...                     484000.0
# DETMERING TIMOTHY J                ...                     415657.0
# DIETRICH JANET R                   ...                     556416.0
# ...                                ...                          ...
# PIRO JIM                           ...                          NaN
# PRENTICE JAMES                     ...                          NaN
# REDMOND BRIAN L                    ...                          NaN
# REYNOLDS LAWRENCE                  ...                     156250.0
# RICE KENNETH D                     ...                    1617011.0
# RIEKER PAULA H                     ...                          NaN
# SCRIMSHAW MATTHEW                  ...                          NaN
# SHANKMAN JEFFREY A                 ...                     554422.0
# SHAPIRO RICHARD S                  ...                          NaN
# SHARP VICTORIA T                   ...                     422158.0
# SHELBY REX                         ...                          NaN
# SHERRICK JEFFREY B                 ...                          NaN
# SHERRIFF JOHN R                    ...                     554422.0
# SKILLING JEFFREY K                 ...                    1920000.0
# STABLER FRANK                      ...                          NaN
# SULLIVAN-SHAKLOVITZ COLLEEN        ...                     554422.0
# SUNDE MARTIN                       ...                     476451.0
# TAYLOR MITCHELL S                  ...                          NaN
# THORN TERENCE H                    ...                     200000.0
# TILNEY ELIZABETH A                 ...                     275000.0
# WALLS JR ROBERT H                  ...                     540751.0
# WALTERS GARETH W                   ...                          NaN
# WASAFF GEORGE                      ...                     200000.0
# WESTFAHL RICHARD K                 ...                     256191.0
# WHALEY DAVID A                     ...                          NaN
# WHALLEY LAWRENCE G            301026.0  False        2796177.0
# WHITE JR THOMAS E            1085463.0  False       13847074.0
# WROBEL BRUCE                       NaN  False              NaN
# YEAGER F SCOTT                147950.0   True        3576206.0
# YEAP SOON                          NaN  False              NaN
#
#                              restricted_stock_deferred     salary  \
# ALLEN PHILLIP K                              -126027.0   201955.0
# BADUM JAMES P                                      NaN        NaN
# BANNANTINE JAMES M                           -560222.0      477.0
# BAXTER JOHN C                                      NaN   267102.0
# BAY FRANKLIN R                                -82782.0   239671.0
# BAZELIDES PHILIP J                                 NaN    80818.0
# BECK SALLY W                                       NaN   231330.0
# BELDEN TIMOTHY N                                   NaN   213999.0
# BELFER ROBERT                                  44093.0        NaN
# BERBERIAN DAVID                                    NaN   216582.0
# BERGSIEKER RICHARD P                               NaN   187922.0
# BIBI PHILIPPE A                                    NaN   213625.0
# BLACHMAN JEREMY M                                  NaN   248546.0
# BOWEN JR RAYMOND M                                 NaN   278601.0
# BUCHANAN HAROLD G                                  NaN   248017.0
# BUTTS ROBERT H                                     NaN   261516.0
# BUY RICHARD B                                      NaN   330546.0
# CALGER CHRISTOPHER F                               NaN   240189.0
# CAUSEY RICHARD A                                   NaN   415189.0
# CHRISTODOULOU DIOMEDES                             NaN        NaN
# CLINE KENNETH W                              -472568.0        NaN
# COLWELL WESLEY                                     NaN   288542.0
# CORDES WILLIAM R                                   NaN        NaN
# COX DAVID                                          NaN   314288.0
# CUMBERLAND MICHAEL S                               NaN   184899.0
# DEFFNER JOSEPH M                                   NaN   206121.0
# DELAINEY DAVID W                                   NaN   365163.0
# DERRICK JR. JAMES V                         -1787380.0   492375.0
# DETMERING TIMOTHY J                          -315068.0   210500.0
# DIETRICH JANET R                                   NaN   250100.0
# ...                                                ...        ...
# PIRO JIM                                           NaN        NaN
# PRENTICE JAMES                                     NaN        NaN
# REDMOND BRIAN L                                    NaN    96840.0
# REYNOLDS LAWRENCE                            -140264.0    76399.0
# RICE KENNETH D                                     NaN   420636.0
# RIEKER PAULA H                                     NaN   249201.0
# SCRIMSHAW MATTHEW                                  NaN        NaN
# SHANKMAN JEFFREY A                                 NaN   304110.0
# SHAPIRO RICHARD S                                  NaN   269076.0
# SHARP VICTORIA T                                   NaN   248146.0
# SHELBY REX                                         NaN   211844.0
# SHERRICK JEFFREY B                                 NaN        NaN
# SHERRIFF JOHN R                                    NaN   428780.0
# SKILLING JEFFREY K                                 NaN  1111258.0
# STABLER FRANK                                      NaN   239502.0
# SULLIVAN-SHAKLOVITZ COLLEEN                        NaN   162779.0
# SUNDE MARTIN                                       NaN   257486.0
# TAYLOR MITCHELL S                                  NaN   265214.0
# THORN TERENCE H                                    NaN   222093.0
# TILNEY ELIZABETH A                                 NaN   247338.0
# WALLS JR ROBERT H                                  NaN   357091.0
# WALTERS GARETH W                                   NaN        NaN
# WASAFF GEORGE                                      NaN   259996.0
# WESTFAHL RICHARD K                                 NaN    63744.0
# WHALEY DAVID A                                     NaN        NaN
# WHALLEY LAWRENCE G                                 NaN   510364.0
# WHITE JR THOMAS E                                  NaN   317543.0
# WROBEL BRUCE                                       NaN        NaN
# YEAGER F SCOTT                                     NaN   158403.0
# YEAP SOON                                          NaN        NaN
#
#                              shared_receipt_with_poi  to_messages  \
# ALLEN PHILLIP K                               1407.0       2902.0
# BADUM JAMES P                                    NaN          NaN
# BANNANTINE JAMES M                             465.0        566.0
# BAXTER JOHN C                                    NaN          NaN
# BAY FRANKLIN R                                   NaN          NaN
# BAZELIDES PHILIP J                               NaN          NaN
# BECK SALLY W                                  2639.0       7315.0
# BELDEN TIMOTHY N                              5521.0       7991.0
# BELFER ROBERT                                    NaN          NaN
# BERBERIAN DAVID                                  NaN          NaN
# BERGSIEKER RICHARD P                           233.0        383.0
# BIBI PHILIPPE A                               1336.0       1607.0
# BLACHMAN JEREMY M                             2326.0       2475.0
# BOWEN JR RAYMOND M                            1593.0       1858.0
# BUCHANAN HAROLD G                               23.0       1088.0
# BUTTS ROBERT H                                   NaN          NaN
# BUY RICHARD B                                 2333.0       3523.0
# CALGER CHRISTOPHER F                          2188.0       2598.0
# CAUSEY RICHARD A                              1585.0       1892.0
# CHRISTODOULOU DIOMEDES                           NaN          NaN
# CLINE KENNETH W                                  NaN          NaN
# COLWELL WESLEY                                1132.0       1758.0
# CORDES WILLIAM R                                58.0        764.0
# COX DAVID                                       71.0        102.0
# CUMBERLAND MICHAEL S                             NaN          NaN
# DEFFNER JOSEPH M                               552.0        714.0
# DELAINEY DAVID W                              2097.0       3093.0
# DERRICK JR. JAMES V                           1401.0       2181.0
# DETMERING TIMOTHY J                              NaN          NaN
# DIETRICH JANET R                              1902.0       2572.0
# ...                                              ...          ...
# PIRO JIM                                         3.0         58.0
# PRENTICE JAMES                                   NaN          NaN
# REDMOND BRIAN L                               1063.0       1671.0
# REYNOLDS LAWRENCE                                NaN          NaN
# RICE KENNETH D                                 864.0        905.0
# RIEKER PAULA H                                1258.0       1328.0
# SCRIMSHAW MATTHEW                                NaN          NaN
# SHANKMAN JEFFREY A                            1730.0       3221.0
# SHAPIRO RICHARD S                             4527.0      15149.0
# SHARP VICTORIA T                              2477.0       3136.0
# SHELBY REX                                      91.0        225.0
# SHERRICK JEFFREY B                             583.0        613.0
# SHERRIFF JOHN R                               2103.0       3187.0
# SKILLING JEFFREY K                            2042.0       3627.0
# STABLER FRANK                                    NaN          NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                      NaN          NaN
# SUNDE MARTIN                                  2565.0       2647.0
# TAYLOR MITCHELL S                              300.0        533.0
# THORN TERENCE H                                 73.0        266.0
# TILNEY ELIZABETH A                             379.0        460.0
# WALLS JR ROBERT H                              215.0        671.0
# WALTERS GARETH W                                 NaN          NaN
# WASAFF GEORGE                                  337.0        400.0
# WESTFAHL RICHARD K                               NaN          NaN
# WHALEY DAVID A                                   NaN          NaN
# WHALLEY LAWRENCE G                            3920.0       6019.0
# WHITE JR THOMAS E                                NaN          NaN
# WROBEL BRUCE                                     NaN          NaN
# YEAGER F SCOTT                                   NaN          NaN
# YEAP SOON                                        NaN          NaN
#
#                              total_payments  total_stock_value
